# %% [markdown]
# <a href="https://colab.research.google.com/github/yadgire7/CODEFORCES/blob/master/hands_on_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import matplotlib.pyplot as plt
import librosa, librosa.display
import IPython.display as ipd

# %%
folder_path = "/content/drive/MyDrive/SAIL/sample_audio/"
piano_file = "piano.mp3"
drum_file = "drum.mp3"

# %%
# load files
piano, p_sr = librosa.load(os.path.join(folder_path, piano_file))
drum, d_sr= librosa.load(os.path.join(folder_path, drum_file))

# %% [markdown]
# # https://librosa.org/doc/main/generated/librosa.load.html
# librosa.load(path of the audio file)
# returns : ndarray (vector representation of the audio wave), smaple rate

# %%
piano, p_sr
# Out:
# (array([ 3.3013523e-05, -1.0190159e-04, -3.3088028e-05, ...,
#          5.1850565e-03,  2.2315630e-04, -2.8103613e-04], dtype=float32),
#  22050)

# %%
len(piano)
# Out:
# 308720

# %%
drum, d_sr
# Out:
# (array([ 1.2134522e-05, -1.6918988e-05, -9.1362745e-07, ...,
#         -5.4758559e-03, -5.2386164e-03, -5.5949511e-03], dtype=float32),
#  22050)

# %%
len(drum)
# Out:
# 151921

# %%
def plot_spectrogram(signal, name):
  spectrogram = librosa.amplitude_to_db(librosa.stft(signal))
  plt.figure(figsize=(20,15))
  librosa.display.specshow(spectrogram, y_axis= "log")
  plt.colorbar(format = "%+2.0f dB")
  plt.title(f"Log-frequency power spectrogram for {name}")
  plt.xlabel("Time")
  plt.show()

# %%
plot_spectrogram(drum, "drum")
# Out:
# <ipython-input-20-dac86846a87b>:2: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   spectrogram = librosa.amplitude_to_db(librosa.stft(signal))

# %%
plot_spectrogram(piano, "piano")
# Out:
# <ipython-input-20-dac86846a87b>:2: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   spectrogram = librosa.amplitude_to_db(librosa.stft(signal))
